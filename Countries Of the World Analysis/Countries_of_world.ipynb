# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Content" data-toc-modified-id="Content-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Content</a></span></li><li><span><a href="#Acknowledgements" data-toc-modified-id="Acknowledgements-1.1"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Acknowledgements</a></span></li><li><span><a href="#Inspiration" data-toc-modified-id="Inspiration-1.4"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Inspiration</a></span></li></ul></li><li><span><a href="#Dataset-Information" data-toc-modified-id="Dataset-Information-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Dataset Information</a></span><ul class="toc-item"><li><span><a href="#Import-'Countries-of-The-World'-Dataset" data-toc-modified-id="Import-'Countries-of-The-World'-Dataset-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Import 'Countries of The World' Dataset</a></span></li><li><span><a href="#Original-Dataset" data-toc-modified-id="Original-Dataset-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Original Dataset</a></span></li></ul></li><li><span><a href="#Data-cleaning" data-toc-modified-id="Data-cleaning-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data cleaning</a></span><ul class="toc-item"><li><span><a href="#Updated-Dataset" data-toc-modified-id="Updated-Dataset-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Updated Dataset</a></span></li></ul></li><li><span><a href="#Findings-from-Dataset" data-toc-modified-id="Findings-from-Dataset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Findings from Dataset</a></span><ul class="toc-item"><li><span><a href="#1.-On-Infant-Mortality" data-toc-modified-id="1.-On-Infant-Mortality-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>1. On Infant Mortality</a></span><ul class="toc-item"><li><span><a href="#Infant-Mortality-Per-Country" data-toc-modified-id="Infant-Mortality-Per-Country-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Infant Mortality Per Country</a></span></li><li><span><a href="#Infant-Mortality-and-Other-Variables" data-toc-modified-id="Infant-Mortality-and-Other-Variables-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Infant Mortality and Other Variables</a></span></li><li><span><a href="#GDP-of-Top-10-Countries-with-Highest-Literacy" data-toc-modified-id="GDP-of-Top-10-Countries-with-Highest-Literacy-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>GDP of Top 10 Countries with Highest Literacy</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Conclusion</a></span></li><li><span><a href="#Managerial-Insights" data-toc-modified-id="Managerial-Insights-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Managerial Insights</a></span></li></ul></li><li><span><a href="#2.-On-Birthrate" data-toc-modified-id="2.-On-Birthrate-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>2. On Birthrate</a></span><ul class="toc-item"><li><span><a href="#Birthrate-and-Other-Variables" data-toc-modified-id="Birthrate-and-Other-Variables-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Birthrate and Other Variables</a></span></li><li><span><a href="#Statistical-Calculation" data-toc-modified-id="Statistical-Calculation-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Statistical Calculation</a></span></li><li><span><a href="#Birthrates-Per-Country" data-toc-modified-id="Birthrates-Per-Country-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Birthrates Per Country</a></span></li><li><span><a href="#Birthrates-Per-Region" data-toc-modified-id="Birthrates-Per-Region-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Birthrates Per Region</a></span></li><li><span><a href="#Infant-Mortality-vs-GDP" data-toc-modified-id="Infant-Mortality-vs-GDP-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Infant Mortality vs GDP</a></span></li><li><span><a href="#Agriculture-vs-GDP" data-toc-modified-id="Agriculture-vs-GDP-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Agriculture vs GDP</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-4.2.7"><span class="toc-item-num">4.2.7&nbsp;&nbsp;</span>Conclusion</a></span></li><li><span><a href="#Managerial-Insights" data-toc-modified-id="Managerial-Insights-4.2.8"><span class="toc-item-num">4.2.8&nbsp;&nbsp;</span>Managerial Insights</a></span></li></ul></li><li><span><a href="#On-GDP" data-toc-modified-id="On-GDP-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>On GDP</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Decision Tree</a></span></li><li><span><a href="#Findings-from-the-above-decision-tree:" data-toc-modified-id="Findings-from-the-above-decision-tree:-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Findings from the above decision tree:</a></span></li><li><span><a href="#Findings:" data-toc-modified-id="Findings:-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Findings:</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Conclusion</a></span></li><li><span><a href="#Managerial-insights" data-toc-modified-id="Managerial-insights-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Managerial insights</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Introduction

# %% [markdown]
#  Data - Countries Of The World

# %% [markdown]
# ## Content
# Information on population, region, area size, infant mortality and more.
#
# ## Acknowledgements
#
# Source: All these data sets are made up of data from the US government. Generally they are free to use if you use the data in the US. If you are outside of the US, you may need to contact the US Govt to ask. Data from the World Factbook is public domain. The website says "The World Factbook is in the public domain and may be used freely by anyone at anytime without seeking permission."
# https://www.cia.gov/library/publications/the-world-factbook/docs/faqs.html
#
# ## Inspiration
#
# When making visualisations related to countries, sometimes it is interesting to group them by attributes such as region, or weigh their importance by population, GDP or other variables.

# %% [markdown]
# # Dataset Information

# %% [markdown]
# <ol>
#
# <li><b>Country</b>: Country of the world.</li>
# <li><b>Region</b>: The geographic regions of the world can be divided into: Africa, Asia, Central America, Eastern Europe, European Union, Middle East, North America, Oceania, South America, and the Caribbean.</li>
# <li><b>Population</b>: Population of a country.</li>
# <li><b>Area</b>: Area of the country in (sq. mi.)</li>
# <li><b>Pop. Density (per sq. mi.)</b>: Population Density per square miles.</li>
# <li><b>Coastline (coast/area ratio)</b>:  The length of coastline in each country.</li>
# <li><b>Net migration</b>: The net total of migrants during the period, that is, the total number of immigrants less the annual number of emigrants, including both citizens and noncitizens.</li>
# <li><b>Infant mortality (per 1000 births)</b>: The number of deaths of infants under one year old in a given year per 1,000 live births in the same year.</li>
# <li><b>GDP ($ per capita)</b>: The Gross Domestic Product measures the <b> value of economic activity </b>within a country. It is the sum of the market values, or prices, of all final goods and services produced in an economy during a period of time.</li>
# <li><b>Literacy (%)</b>: Literacy is a key skill and a key measure of a population’s education.</li>
# <li><b>Phones (per 1000)</b>: Number of phones used per 1000</li>
# <li><b>Arable (%)</b>: The land capable of being ploughed and used to grow crops, Cultivatable Land</li>
# <li><b>Crops (%)</b>: A crop is a plant or plant product that can be grown and harvested for profit or subsistence.</li>
# <li><b>Other (%)</b>:Other factors that contribute to the GDP</li>
# <li><b>Climate</b>: CO2 emissions (metric tons per capita) </li>
# <li><b>Birthrate</b>: Birth rate compares the average annual number of births during a year per 1,000 persons in the population at midyear; also known as crude birth rate</li>
# <li><b>Deathrate</b>: Death rate compares the average annual number of deaths during a year per 1,000.</li>
# <li><b>Agriculture</b>:  They include <b>value added </b>in Agriculture by cultivating plants and livestock.</li>
# <li><b>Industry</b>: An industry is the production of goods or related services within an economy, It comprises<b> value added</b> in <b>mining, manufacturing, construction, electricity, water, and gas.</b></li>
# <li><b>Service</b>:  They include <b>value added </b>in wholesale and retail trade (including hotels and restaurants), transport, and government, financial, professional, and personal services such as education, health care, and real estate services to the GDP of the Country</li>

# %% [markdown]
# ## Import 'Countries of The World' Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.plotly as py

from scipy import stats
import scipy.stats as sts
from sklearn import linear_model
from sklearn import datasets
import plotly.graph_objs as ply
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
from sklearn.linear_model import LinearRegression
import sklearn.tree as tree
from IPython.display import Image  
import pydotplus
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
world_data = pd.read_csv("countries.csv")

# %%
world_data.shape
# Out:
# (227, 20)

# %% [markdown]
# ## Original Dataset

# %%
world_data.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
world_data
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# ...

# %% [markdown]
# # Data cleaning

# %% [markdown]
# <li>Renaming column names for readability purpose.</li>

# %%
world_data.columns = (["Country","Region","Population","Area",\
                       "Density","Coastline","Migration","Infant_mortality",\
                       "GDP","Literacy","Phones","Arable","Crops","Other",\
                       "Climate","Birthrate","Deathrate","Agriculture","Industry","Service"])

world_data.head()
# Out:
#            Country                               Region  Population     Area  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997   647500
# 1         Albania   EASTERN EUROPE                          3581655    28748
# 2         Algeria   NORTHERN AFRICA                        32930091  2381740
# 3  American Samoa   OCEANIA                                   57794      199
# 4         Andorra   WESTERN EUROPE                            71201      468
#
#   Density Coastline Migration Infant_mortality      GDP Literacy Phones  \
# 0    48,0      0,00     23,06           163,07    700.0     36,0    3,2
# 1   124,6      1,26     -4,93            21,52   4500.0     86,5   71,2
# 2    13,8      0,04     -0,39               31   6000.0     70,0   78,1
# 3   290,4     58,29    -20,71             9,27   8000.0     97,0  259,5
# 4   152,1      0,00       6,6             4,05  19000.0    100,0  497,2
#
# ...

# %% [markdown]
# <li>Create coutry and region as categories. </li>

# %%
world_data.Country = world_data.Country.astype('category')
world_data.Region = world_data.Region.astype('category')

# %% [markdown]
# <li>Update datatypes of columns from string to float and replace ',' with '.' to be used in further predictions.</li>

# %%
world_data.Density = world_data.Density.str.replace(",",".").astype(float)
world_data.Coastline = world_data.Coastline.str.replace(",",".").astype(float)
world_data.Migration = world_data.Migration.str.replace(",",".").astype(float)
world_data.Infant_mortality = world_data.Infant_mortality.str.replace(",",".").astype(float)
world_data.Literacy = world_data.Literacy.str.replace(",",".").astype(float)
world_data.Phones = world_data.Phones.str.replace(",",".").astype(float)
world_data.Arable = world_data.Arable.str.replace(",",".").astype(float)
world_data.Crops = world_data.Crops.str.replace(",",".").astype(float)
world_data.Other = world_data.Other.str.replace(",",".").astype(float)
world_data.Climate = world_data.Climate.str.replace(",",".").astype(float)
world_data.Birthrate = world_data.Birthrate.str.replace(",",".").astype(float)
world_data.Deathrate = world_data.Deathrate.str.replace(",",".").astype(float)
world_data.Agriculture = world_data.Agriculture.str.replace(",",".").astype(float)
world_data.Industry = world_data.Industry.str.replace(",",".").astype(float)
world_data.Service = world_data.Service.str.replace(",",".").astype(float)

# %% [markdown]
# <li>Check and Drop NANs from the dataset.</li>

# %%
world_data.isna().sum()
# Out:
# Country              0
# Region               0
# Population           0
# Area                 0
# Density              0
# Coastline            0
# Migration            3
# Infant_mortality     3
# GDP                  1
# Literacy            18
# Phones               4
# Arable               2
# Crops                2
# Other                2
# Climate             22
# Birthrate            3
# Deathrate            4
# Agriculture         15
# Industry            16
# Service             15
# dtype: int64

# %%
world_data = world_data.dropna()

# %% [markdown]
# ## Updated Dataset

# %%
world_data.head()
# Out:
#               Country                               Region  Population  \
# 0        Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1            Albania   EASTERN EUROPE                          3581655
# 2            Algeria   NORTHERN AFRICA                        32930091
# 6           Anguilla               LATIN AMER. & CARIB           13477
# 7  Antigua & Barbuda               LATIN AMER. & CARIB           69108
#
#       Area  Density  Coastline  Migration  Infant_mortality      GDP  \
# 0   647500     48.0       0.00      23.06            163.07    700.0
# 1    28748    124.6       1.26      -4.93             21.52   4500.0
# 2  2381740     13.8       0.04      -0.39             31.00   6000.0
# 6      102    132.1      59.80      10.76             21.03   8600.0
# 7      443    156.0      34.54      -6.15             19.46  11000.0
#
#    Literacy  Phones  Arable  Crops   Other  Climate  Birthrate  Deathrate  \
# ...

# %%
world_data
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# 11              Australia   OCEANIA                                20264082
# 12                Austria   WESTERN EUROPE                          8192880
# 13             Azerbaijan                  C.W. OF IND. STATES      7961619
# ...

# %% [markdown]
# # Findings from Dataset

# %% [markdown]
# ## 1. On Infant Mortality

# %% [markdown]
# ### Infant Mortality Per Country

# %% [markdown]
# The infant mortality rate is the number of infant deaths for every 1,000 live births.

# %%
data = dict(type='choropleth',locations = world_data.Country, \
            locationmode = 'country names', z = world_data.Infant_mortality,\
            text = world_data.Country, colorbar = {'title':'Infant Mortality'},
colorscale = 'YlOrRd', reversescale = True)
layout = dict(title='Infant Mortality per Country',
geo = dict(showframe=False, projection={'type':'natural earth'}))
choromap = ply.Figure(data = [data],layout = layout)
iplot(choromap,validate=False)
# Out:
# <div>
#
#
#             <div id="2b9587f3-c4f9-4e5c-9abb-af4c827e66a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2b9587f3-c4f9-4e5c-9abb-af4c827e66a5")) {
#                     Plotly.newPlot(
#                         '2b9587f3-c4f9-4e5c-9abb-af4c827e66a5',
# ...

# %% [markdown]
# From the world map above, it is clear that countries like, Sweden, Portland, Denmark and Australia has lowest rate of infant mortality, whereas countries from Sub-Saharan Africa and Afganistan has highest mortality rate. Below, we want to figure out infant mortality's relationship with other variables:

# %% [markdown]
# ### Infant Mortality and Other Variables

# %%
x = world_data.loc[:,["Region", "Literacy", "Infant_mortality"]]
sns.pairplot(x, hue="Region",palette="inferno")
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %%
x = world_data.loc[:,["Region", "Birthrate", "Infant_mortality"]]
sns.pairplot(x, hue="Region",palette="inferno")

# %%
sns.lmplot(x="Infant_mortality", y="Literacy", data=world_data, height=5)

# %%
sns.lmplot(x="Infant_mortality", y="Birthrate", data=world_data, height=5)

# %% [markdown]
# From these correlation graphs, countries/regions with high infant mortalities are highly co-related with high birthrate and low literacy. Before we conclude, lets look at GDP of Top 10 coutries with highest literacy.

# %% [markdown]
# ### GDP of Top 10 Countries with Highest Literacy

# %%
lit = world_data.sort_values("Literacy", ascending=False).head(10)
fig = {
  "data": [
    {
      "values": lit.GDP,
      "labels": lit.Country,
      "domain": {"x": [0, .5]},
      "name": "GDP percentage of",
      "hoverinfo":"label+percent+name",
      "hole": .3,
      "type": "pie"
    },],
  "layout": {
        "title":"GDP of top 10 country(literacy)",
        "annotations": [
            { "font": { "size": 15},
              "showarrow": False,
              "text": "GDP",
                "x": 0.22,
                "y": 0.5
            },
        ]
    }
}
iplot(fig)
# Out:
# <div>
#
#
#             <div id="9e261fe3-59c1-40fc-91a9-8003c9aabff7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9e261fe3-59c1-40fc-91a9-8003c9aabff7")) {
#                     Plotly.newPlot(
#                         '9e261fe3-59c1-40fc-91a9-8003c9aabff7',
# ...

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - We initially found that infant mortality and Literacy are significantly negatively correlated.
# - We found that Sub-Saharan Africa region has the highest infant mortality rate.
# - Pie chart explains literacy has the positive correlation between GDP. As more a country with higher literacy has better awareness about healthcare for the newborns and higher GDP to provide right environment for survival of newborns.

# %% [markdown]
# ### Managerial Insights

# %% [markdown]
# The region/countries having higher infant mortality rate government should focus on improving education system, so that the literacy rate will be improved; and will result into higher GDP and lower infant mortality rate.

# %% [markdown]
# ## 2. On Birthrate

# %% [markdown]
# ### Birthrate and Other Variables

# %% [markdown]
# Below are different graphs to visualize the relationship between birthrates and all other variables.

# %%
# a plot to visualize the correlation between variables
corr = world_data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(world_data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(world_data.columns)
ax.set_yticklabels(world_data.columns)
plt.show()

# %%
# a more specific visualization of the relationship/correlation between variables

f, ax = plt.subplots(figsize = (20,10))
sns.heatmap(world_data.corr(), annot = True, linewidth = 0.5, fmt = ".1f", ax=ax, cmap='coolwarm')
plt.show()

# %%
sns.clustermap(world_data.corr(), cmap = 'coolwarm')

# %% [markdown]
# From the graphs and series created above, we can see a strong direct correlation between birthrate, and infant mortality and agriculture, as well as a strong inverse correlation between birthrate, and GDP, literacy, and phones. To narrow down the list, we want to find the variables that are significantly correlated with birthrate.

# %% [markdown]
# ### Statistical Calculation

# %% [markdown]
# Below, we will calculate the z-scores, and then the p-values, to find the correlations that are most significant, using a threshold of p < 0.05.

# %%
# create a series that lists correlations between birthrate and all variables
birth = world_data.corr().Birthrate.drop('Birthrate')

# %%
# calculate z-scores of the correlation of birth with all other variables
z_scores = stats.zscore(birth)

# %%
# using the z-scores found above to calculate p-values
p_value = sts.norm.sf(abs(z_scores))
p_value = pd.Series(p_value).reset_index()

# %%
birth = birth.reset_index()

# %%
# merging dataframe with p-value
pd.merge(birth, p_value, right_index=True, left_index=True).drop(columns=['index_y', 'Birthrate']).\
            rename(columns={"index_x": "Variables", 0: "P_Value"}).nsmallest(3, 'P_Value')
# Out:
#            Variables   P_Value
# 5   Infant_mortality  0.017031
# 14       Agriculture  0.038351
# 7           Literacy  0.063615

# %% [markdown]
# After calculating the z-scores and p-values, we found that the only infant mortality and agriculture are significantly correlated with birthrate.

# %% [markdown]
# ### Birthrates Per Country

# %%
# create barplot to show relationship between countries and birthrate
plt.figure(figsize=(15,30))
sns.set()
sns.barplot(x=world_data["Birthrate"].sort_values(ascending = False),y = world_data["Country"].unique(), color = 'yellow')
plt.xlabel("Birthrate")
plt.ylabel("Country")
plt.title("Birthrate-Country")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Birthrates Per Region

# %%
# show relationship between region and birthrate
reg = world_data.groupby("Region")
reg["Birthrate"].sum()
# Out:
# Region
# ASIA (EX. NEAR EAST)                    534.45
# BALTICS                                  19.28
# C.W. OF IND. STATES                     188.62
# EASTERN EUROPE                           64.05
# LATIN AMER. & CARIB                     805.26
# NEAR EAST                               298.31
# NORTHERN AFRICA                          55.60
# NORTHERN AMERICA                         25.54
# OCEANIA                                 252.88
# SUB-SAHARAN AFRICA                     1702.34
# WESTERN EUROPE                          182.75
# Name: Birthrate, dtype: float64

# %% [markdown]
# ### Infant Mortality vs GDP

# %% [markdown]
# We have found that infant mortality is significantly positively correlated with birthrate. We speculate that this relationship exist because infant mortality is inversely correlated with GDP. To illustrate this further, we have created several plots to visualize the relationship between infant mortality and GDP.

# %%
# create scatterplot to show relationship between GDP and infant mortality
x = world_data['GDP'].values
y = world_data['Infant_mortality'].values
m = corr.loc['GDP', 'Infant_mortality']
plt.scatter(x, y)
plt.text(10**4, 100, '%s: %s' %('Correlation:', np.round(m, 2)))
plt.xscale('log')
plt.xlabel('GDP')
plt.ylabel('Infant_Mortality')
# Out:
# Text(0,0.5,'Infant_Mortality')

# %%
world_data.sort_values('Infant_mortality', ascending = False)
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 183          Sierra Leone   SUB-SAHARAN AFRICA                      6005250
# 142            Mozambique   SUB-SAHARAN AFRICA                     19686505
# 117               Liberia   SUB-SAHARAN AFRICA                      3042004
# 151                 Niger   SUB-SAHARAN AFRICA                     12525094
# 128                  Mali   SUB-SAHARAN AFRICA                     11716829
# 188               Somalia   SUB-SAHARAN AFRICA                      8863338
# 199            Tajikistan                  C.W. OF IND. STATES      7320815
# 87          Guinea-Bissau   SUB-SAHARAN AFRICA                      1442029
# 55               Djibouti   SUB-SAHARAN AFRICA                       486530
# 125                Malawi   SUB-SAHARAN AFRICA                     13013926
# ...

# %% [markdown]
# The graphs above shows that is a relationship between GDP and infant mortality, and their relationship is inversely correlated. Meaning that if GDP increases, infant mortality decrease. We also sorted the dataframe to see which countries have the highest infant mortality. Turns out most of these countries are in Sub-Saharan Africa and have lower GDP compared to many other countries.

# %% [markdown]
# ### Agriculture vs GDP

# %% [markdown]
# We have found that agriculture is significantly positively correlated with birthrate. We speculate that this relationship exist because agriculture is inversely correlated with GDP. To illustrate this further, we have created several plots to visualize the relationship between agriculture and GDP.

# %%
# create scatterplot to show relationship between GDP and agriculture
x = world_data['GDP'].values
y = world_data['Agriculture'].values
m = corr.loc['GDP', 'Agriculture']
plt.scatter(x, y)
plt.text(10**4, 0.6, '%s: %s' %('Correlation:', np.round(m, 2)))
plt.xscale('log')
plt.xlabel('GDP')
plt.ylabel('Agriculture')
# Out:
# Text(0,0.5,'Agriculture')

# %% [markdown]
# The graphs above shows that there is indeed a relationship between GDP and agriculture, and their relationship is inversely correlated. Meaning that if GDP increases, agriculture increases.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# 1. We initially found that infant mortality and agriculture are significantly positively correlated with birthrate. To explain this relationship, we speculate infant mortality and agriculture are inversely correlated with GDP per capita.
#
#
# 2. We found that Sub-Saharan Africa region has the highest birthrate, and 8 out of 10 of the countries with highest infant mortality rates are in Sub-Saharan Africa. These countries generally have lower GDP per capita compared to many other countries.
#
#
# 3. GDP per capita can explain the positive correlation between infant mortality and birhrate because a country with low GDP could potentially have difficulty providing the right environment and healthcare for the newborns to survive. However, we did not have the proper data to conduct an accurate analysis of that. From our analysis, we can only conclude that birthrate and infant mortality are directly correlated, and infant mortality and GDP are inversely correlated.
#
#
# 4. GDP per capita also explains the positive correlation between agriculture and birthrate because we think that a country with low GDP is more likely to be invested in the agriculture domain instead of the industry domain and service domain. We think that it could also be that a country has low GDP per capita because they are in the agriculture domain and not industry nor service domain. Since agriculture is inversely correlated with GDP, we speculate that it could be one of the explanations for the positive relationship between agriculture and birthrate. This is again an opinion of our group and not a causation analysis since we did not use appropriate data and methods for the analysis.

# %% [markdown]
# ### Managerial Insights

# %% [markdown]
# A country in the Sub-Saharan Africa region could potentially be worried about its high birthrate and high infant mortality. With this information, they know that birthrate is positively correlated with agriculture, and birthrate is positively correlated with infant mortality. Meaning that, if agriculture decreases, birthrate decreases, and infant mortality could potentially decrease as well. We, however, do not have the data to confirm the sequence of events, and the causation of each variable. Hence, the country could look into one of these factors to study deeply into the causation of each variables and how an increase in agriculture/birthrate/infant mortality can affect the others.
#
#
# They also know that there is an inverse relationship between GDP and agriculture, and GDP and infant mortality. They could perhaps switch their focus to invest more in the industry and/or service domain, since there is a correlation of a higher GDP in those domains. And when GDP rises, it could potentially reduce the amount of infant mortality, and because infant mortality is postively correlated with birthrate, there is a potential of decrease in birthrate. Hence, to manage his/her country's birthrate, he/she could look into how the GDP per capita of their country affects birthrate.

# %% [markdown]
# ## On GDP

# %% [markdown]
# In this part we perform analysis of factors that can be possible causations of high or low GDP using Machine Learning.

# %% [markdown]
# Firstly, let's find the average GDP value around the world from this dataset.

# %%
world_data.GDP.mean()
# Out:
# 9125.698324022347

# %% [markdown]
# And remove variables that logically can`t be causations:

# %%
df_gdp = world_data.drop(['Country','Region', 'Infant_mortality', 'Phones'], axis=1)

# %% [markdown]
# GDP of 10000 is taken for intial arranging of GDP values in 2 categories: high (>10000) and low (<10000)

# %%
df_gdp['GDP_high'] = df_gdp.GDP > 10000

# %% [markdown]
# ### Decision Tree

# %%
X = df_gdp.drop(['GDP_high','GDP'], axis=1)
Y = df_gdp['GDP_high']
dt = tree.DecisionTreeClassifier(max_depth=3)
dt.fit(X,Y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dt_feature_names = list(X.columns)
dt_target_names = [str(s) for s in Y.unique()]
tree.export_graphviz(dt, out_file='tree.dot', 
    feature_names=dt_feature_names, class_names=dt_target_names,\
    filled=True) 
graph = pydotplus.graph_from_dot_file('tree.dot')
Image(graph.create_png())

# %% [markdown]
# ### Findings from the above decision tree:
#
# - Agriculture level is the main predictor that decision tree used to build the tree. Specifically, 6% is a borderline. Countries that have more than 6% of GDP from agriculture field - have low GDP as well.
# - Another predictor is migration level. If migration level is dropping less than -4.015 (which means that more and more people emigrate from their countries) it is related to low GDP.
# - Other predictors did't show anything interesting, and the third level of the decision tree unfortunately is not helpful.

# %% [markdown]
# Let's plot a barchart showing the relationship of agriculture level and GDP (High or Low).

# %%
sns.barplot(x='GDP_high',y='Agriculture', data=df_gdp)

# %% [markdown]
# Also, for migration:

# %%
sns.barplot(x='GDP_high',y='Migration', data=df_gdp)

# %% [markdown]
# The plot clearly shows that countries with high GDP have positive migration, and it is completely opposite for countries with low GDP.

# %% [markdown]
# Let's also do the decision tree analysis considering top 25 countries by GDP.

# %%
world_data.GDP.nlargest(25)
# Out:
# 154    37800.0
# 214    37800.0
# 22     36000.0
# 38     35000.0
# 196    32700.0
# 54     31100.0
# 93     30900.0
# 12     30000.0
# 98     29600.0
# 19     29100.0
# 11     29000.0
# 91     28800.0
# 146    28600.0
# 103    28200.0
# 10     28000.0
# 213    27700.0
# 69     27600.0
# 76     27600.0
# 68     27400.0
# 195    26800.0
# 119    25000.0
# 184    23700.0
# 198    23400.0
# 212    23200.0
# 190    22000.0
# Name: GDP, dtype: float64

# %%
df_gdp['GDP_high'] = df_gdp.GDP >= 22000

# %%
X = df_gdp.drop(['GDP_high','GDP'], axis=1)
Y = df_gdp['GDP_high']
dt = tree.DecisionTreeClassifier(max_depth=3)
dt.fit(X,Y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dt_feature_names = list(X.columns)
dt_target_names = ['Low','High']
tree.export_graphviz(dt, out_file='tree.dot', 
    feature_names=dt_feature_names, class_names=dt_target_names,\
    filled=True) 
graph = pydotplus.graph_from_dot_file('tree.dot')
Image(graph.create_png())

# %% [markdown]
# ### Findings:
# - Agriculture level is again the main predictor, but this time it dropped to 0.023.
# - Birthrate became a predictor. Top 25 countries by GDP have birthrates less than 12.755 (for every 1000 people)
# - Other predictors are not very important or dividing only very small number of countries.

# %%
sns.barplot(x='GDP_high',y='Agriculture', data=df_gdp)

# %%
sns.barplot(x='GDP_high',y='Birthrate', data=df_gdp)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The purpose of this part was to use a machine learning model to try to understand why some countries have high GDP and others don't, and also to find factors/variables that can be reasons. We built two decision trees, one is based on mean GDP as borderline between high and low, and the second one is about top 25 countries by GDP. To sum up from the above decision tree classification:
#
# 1. Pupulation, area, density, coastline: they have nothing to do with GDP.
#
# 2. Main predictor is agriculture level. Countries with high GDP have very small level of agriculture. Top 25 countries by GDP have agriculture level no more than 2.3%, while in some countries with low GDP it can reach 30%.
#
# 3. Migration and birthrate are also factors that play important role in classification. Birthrate in countries with high GDP is around two times less compared to other countries. 13 births for 1000 people is the borderline for the top 25. Migration is positive in countries with high GDP and negative in countries with low GDP.

# %% [markdown]
# ### Managerial insights

# %% [markdown]
# GDP is really complicated topic and there can be many factors that may cause GDP to raise or fall. This part is strongly based just on the data we have and the results of decision tree classifier. From the above analysis we can propose the following managerial insights:
#
# - Countries that have very high agriculture level should focus on other fields. It doesn't mean that they need to just stop doing agriculture, although they need to develop other fields and develop educational system to improve percentage of highly-educated people that can improve those fields.
#
# - Migration should be positive. Countries with low GDP need to create such conditions for their citizens that will lower emigration and prevent smart people from moving out of those countries. Easy to say, hard to do, but this is a very important factor.
#
# - Birthrate. Very obvious difference between countries with high GDP and low GDP. It's really hard to change birthrate statistics in any country, so giving any recommendations just based just on this data analysis not really possible. There is no country in top 25 GDP with high birthrate, so this aspect should be taken into serious consideration by governments of countries that are planning to achieve high GDP.
